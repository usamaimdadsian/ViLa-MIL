# %%
# !git clone https://github.com/usamaimdadsian/ViLa-MIL.git
# Out:
# Cloning into 'ViLa-MIL'...
# remote: Enumerating objects: 181, done.
# remote: Counting objects: 100% (181/181), done.
# remote: Compressing objects: 100% (128/128), done.
# remote: Total 181 (delta 80), reused 88 (delta 37), pack-reused 0 (from 0)
# Receiving objects: 100% (181/181), 5.76 MiB | 11.39 MiB/s, done.
# Resolving deltas: 100% (80/80), done.

# %%
# %cd /content/ViLa-MIL
# Out:
# /content/ViLa-MIL

# %%
# !cp /content/drive/MyDrive/patch_features.zip ./

# %%
# !unzip patch_features.zip -d ./
# Out:
# Archive:  patch_features.zip
#    creating: ./patch_features/
#    creating: ./patch_features/large/
#   inflating: ./patch_features/large/TCGA-92-7340-01A-01-BS1.2d01a95e-5416-4195-aa60-a0432ea38258.h5
#   inflating: ./patch_features/large/TCGA-85-A512-01Z-00-DX1.154BBD51-803C-46F0-840E-D2597E648365.h5
#   inflating: ./patch_features/large/TCGA-38-4632-01A-01-TS1.eb6e2e6b-89bd-440c-9fc8-d932b5491654.h5
#   inflating: ./patch_features/large/TCGA-05-4398-01A-01-TS1.061af2c7-1143-430d-8286-1996405ab057.h5
#   inflating: ./patch_features/large/TCGA-86-8279-01Z-00-DX1.fd12b60e-d181-454b-a655-298a973a849d.h5
#   inflating: ./patch_features/large/TCGA-33-4566-01Z-00-DX1.C256546D-D3EC-41DA-9681-06BA4B011DD2.h5
#   inflating: ./patch_features/large/TCGA-49-AARQ-01A-01-TS1.8C48AD1A-1DFB-4DCD-AD01-4DB9C2ED73B1.h5
#   inflating: ./patch_features/large/TCGA-O2-A52Q-01A-01-TSA.1C75AE48-43E2-49E6-A499-597176CFCC5A.h5
# ...

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 25.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 kB 20.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached pybind11-2.6.1-py2.py3-none-any.whl.metadata (8.7 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 10.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 8.1 MB/s eta 0:00:00
# Using cached pybind11-2.6.1-py2.py3-none-any.whl (188 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 5.1 MB/s eta 0:00:00
# ...
#   Created wheel for openai-clip: filename=openai_clip-1.0.1-py3-none-any.whl size=1368605 sha256=0a9f6b91c1cd14de7b39394bad48e07606a5cd76cf428d9b7409464994aad2c0
#   Stored in directory: /root/.cache/pip/wheels/08/77/8e/8d2f862df6bf7fb4e2007062d2cbaeae49862ec7b56d041229
# ...

# %%
# !sh taining.sh
# Out:
# Load Dataset
# label column: label
# label dictionary: {'normal': 0, 'abnormal': 1}
# number of classes: 2
# slide-level counts:
#  label
# 1     16
# 0    131
# Name: count, dtype: int64
# Patient-LVL; Number of samples registered in class 0: 42
# Slide-LVL; Number of samples registered in class 0: 131
# Patient-LVL; Number of samples registered in class 1: 4
# Slide-LVL; Number of samples registered in class 1: 16
# split_dir:  splits/TCGA_LUNG/task_tcga_lung_subtyping_100
# ################# Settings ###################
# num_splits:  1
# k_start:  -1
# k_end:  -1
# task:  task_tcga_lung_subtyping
# max_epochs:  200
# results_dir:  /content/drive/MyDrive/results
# lr:  0.0001
# experiment:  experiments
# label_frac:  1.0
# seed:  1
# model_type:  ViLa_MIL
# mode:  transformer
# use_drop_out:  True
# weighted_sample:  False
# opt:  adam
# split_dir:  splits/TCGA_LUNG/task_tcga_lung_subtyping_100
#
# Training Fold 0!
#
# Init train/val/test splits...
# Done!
# ...
